# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 18.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 109.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 97.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 65.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 10.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 38.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 10.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 102.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model1 = YOLO("yolov8n.pt")
model1.train(
    data= '/content/drive/MyDrive/First_move_dataset/data.yaml',
    epochs=100,  # Set a high number; early stopping will stop it earlier if needed
    batch=32,
    name="model_starting_frames2",
    patience=10, # Stop if no improvement in validation loss for 10 epochs
    project="/content/drive/MyDrive/YOLO_training_First_move_batch_32_2"
)
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 69.3MB/s]
# Ultralytics 8.3.125 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %%
# TESTING THE MODLE

# Load the trained models
model1 = YOLO("/content/drive/MyDrive/YOLO_training_First_move_batch_32_2/model_starting_frames2/weights/best.pt")

# %%
# Run inference on test images
results1 = model1.predict(source='/content/drive/MyDrive/First_move_dataset/test/images', save=True)
# Out:
# image 1/175 /content/drive/MyDrive/First_move_dataset/test/images/02cfadb3-9ef9-42dc-8234-e149887540a1_0_jpg.rf.e6f43c872012ec8723b5d84842f296af.jpg: 640x640 1 pull-up_1, 8.4ms
# image 2/175 /content/drive/MyDrive/First_move_dataset/test/images/16f29b6d-ed0c-46e5-80e0-8a83fc97d4de_121_jpg.rf.e53bdaacf561eea9713a3985e6440700.jpg: 640x640 1 pull-up_1, 10.9ms
# image 3/175 /content/drive/MyDrive/First_move_dataset/test/images/22d3f939-959a-42e9-bc1b-348d8075bf5d_200_jpg.rf.085232e6e072e7abe4f43a1b3e0e53e1.jpg: 640x640 1 pull-up_1, 8.7ms
# image 4/175 /content/drive/MyDrive/First_move_dataset/test/images/2430f678-71b5-46f4-9943-4549a4306c86_0_jpg.rf.9b957f8e88a052320600ff3bc53731a9.jpg: 640x640 1 pull-up_1, 8.8ms
# image 5/175 /content/drive/MyDrive/First_move_dataset/test/images/2430f678-71b5-46f4-9943-4549a4306c86_270_jpg.rf.d69a0ae6675877b170d87bacd86faeb2.jpg: 640x640 1 pull-up_1, 9.6ms
# ...

# %%
# !cp -r /content/runs /content/drive/MyDrive/YOLO_training_First_move_batch_32_2

# %%
# Evaluate IOU for each model
data_yaml='/content/drive/MyDrive/First_move_dataset/data.yaml'
metrics1 = model1.val(data= data_yaml, split='test')

# Overall metrics
print(f"mAP@50: {metrics1.box.map50:.3f}")
print(f"mAP@50-95: {metrics1.box.map:.3f}")
print(f"Mean Precision: {metrics1.box.mp:.3f}")
print(f"Mean Recall: {metrics1.box.mr:.3f}")

# Per-class mAP
class_maps_3 = metrics1.box.maps
for i, ap in enumerate(class_maps_3):
    print(f"Class {i} ({model1.names[i]}): mAP = {ap:.2f}")
# Out:
# Ultralytics 8.3.125 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# val: Fast image access ✅ (ping: 0.2±0.0 ms, read: 53.6±37.6 MB/s, size: 57.4 KB)
# val: Scanning /content/drive/MyDrive/First_move_dataset/test/labels.cache... 175 images, 0 backgrounds, 0 corrupt: 100%|██████████| 175/175 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:02<00:00,  4.78it/s]
#                    all        175        176      0.991      0.991      0.995      0.892
#        Russian-Twist_1         18         18       0.99          1      0.995      0.937
#          hammer-curl_1         34         34          1      0.956      0.994      0.811
#              pull-up_1         38         38      0.996          1      0.995      0.941
#              push-up_1         44         44      0.999          1      0.995      0.873
# ...

# %%
# Check model complexity (FLOPs)

flops1 = model1.info(verbose=True)
# Out:
# Model summary (fused): 72 layers, 3,006,623 parameters, 0 gradients, 8.1 GFLOPs

# %%
# !cp -r /content/runs /content/drive/MyDrive/YOLO_training_First_move_batch_32_2
